# %%
import os
import json
import pandas as pd

def parse_metadata_files(root_dir):
    # List to hold all the JSON data
    all_data = []

    # Traverse the directory structure
    for subdir, _, files in os.walk(root_dir):
        # Check if dataset-metadata.json is in the current directory
        if 'dataset-metadata.json' in files:
            # Construct the full path to the JSON file
            file_path = os.path.join(subdir, 'dataset-metadata.json')
            # Open and read the JSON file
            with open(file_path, 'r') as json_file:
                data = json.load(json_file)
                if data['description'] != '' and data['keywords'] != []:
                    keywords = data['keywords'][:5] + [''] * (5 - len(data['keywords']))
                    all_data.append((data['title'], data['subtitle'], data['description'], *keywords))

    # Create a DataFrame from the list of JSON data
    df = pd.DataFrame(all_data, columns=['title', 'subtitle', 'description', 'keyword 1', 'keyword 2', 'keyword 3', 'keyword 4', 'keyword 5'])
    return df

# Define the root directory
root_dir = '../datasets/kaggle'

# Parse the metadata files and create the DataFrame
metadata_df = parse_metadata_files(root_dir)

# Display the DataFrame
metadata_df
# Out:
#                                     title  \
# 0     Basic Arabic Vocal Emotions Dataset
# 1     Military Aircraft Detection Dataset
# 2                   Fashion Dataset UK-US
# 3                 CoNIC Challenge Dataset
# 4                          Lizard dataset
# ...                                   ...
# 6812           Suicude rates by countries
# 6813                Yugioh Rush Duel Sets
# 6814                        goodbooks-10k
# 6815                        Sanction Loan
# 6816               crypto nft tweets data
#
#                                                subtitle  \
# 0                 مجموعة بيانات العواطف الصوتية العربية
# 1     military aircraft images with aircraft type an...
# 2     A Comprehensive Dataset for Informed Decision-...
# 3        Patch-level LIZARD dataset for CoNIC Challenge
# 4     The largest known nuclear instance segmentatio...
# ...                                                 ...
# 6812                      Suicude rates by male/female
# 6813        Yugioh Rush Duel Sets, Up To September 2022
# 6814  Ten thousand books, one million ratings. Also ...
# 6815
# 6816  crypto and nft related tweets and sentiments f...
#
#                                             description  \
# 0     Don't forget to upvote the dataset. Thank you....
# 1     ## Overview\nThis dataset is designed for obje...
# 2     The Fashion Sales Dataset is a comprehensive a...
# 3     The dataset consists of Haematoxylin and Eosin...
# 4     The development of deep segmentation models fo...
# ...                                                 ...
# 6812  uicide occurs throughout the world, affecting ...
# 6813  Rush Duel is a new format of Yugioh and being ...
# 6814  **This version of the dataset is obsolete. It ...
# 6815  ### Predict the loan sanction Amount\n\nBuying...
# 6816  NO MORE UPDATES\n[nitter.net](https://nitter.n...
#
#                       keyword 1           keyword 2       keyword 3  \
# 0                         music           education           audio
# 1        arts and entertainment            business        military
# 2      clothing and accessories  data visualization  data analytics
# 3                    healthcare    earth and nature         biology
# 4                       biology
# ...                         ...                 ...             ...
# 6812                categorical               crime        beginner
# 6813                      games            beginner            text
# 6814                 literature
# 6815  exploratory data analysis  data visualization  classification
# 6816                text mining             tabular            text
#
#                             keyword 4            keyword 5
# 0                  online communities
# 1                            aviation      computer vision
# 2
# 3                              health             medicine
# 4
# ...                               ...                  ...
# 6812                     intermediate             advanced
# 6813                            japan      anime and manga
# 6814
# 6815              feature engineering           regression
# 6816  currencies and foreign exchange  text classification
#
# [6817 rows x 8 columns]

# %%
metadata_df.to_csv('../datasets/kaggle_metadata.csv', index=False)
